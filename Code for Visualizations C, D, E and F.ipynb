isinstance(data, pd.DataFrame) or hasattr(data, "__geo_interface__"):
# ---> 89     data = _pipe(data, data_transformers.get())
#      91 # convert string input to a URLData
#      92 if isinstance(data, str):
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/toolz/functoolz.py:628, in pipe(data, *funcs)
#     608 """ Pipe a value through a sequence of functions
#     609
#     610 I.e. ``pipe(data, f, g, h)`` is equivalent to ``h(g(f(data)))``
#    (...)
#     625     thread_last
#     626 """
#     627 for func in funcs:
# --> 628     data = func(data)
#     629 return data
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/toolz/functoolz.py:304, in curry.__call__(self, *args, **kwargs)
#     302 def __call__(self, *args, **kwargs):
#     303     try:
# --> 304         return self._partial(*args, **kwargs)
#     305     except TypeError as exc:
#     306         if self._should_curry(args, kwargs, exc):
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/altair/vegalite/data.py:19, in default_data_transformer(data, max_rows)
#      17 @curried.curry
#      18 def default_data_transformer(data, max_rows=5000):
# ---> 19     return curried.pipe(data, limit_rows(max_rows=max_rows), to_values)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/toolz/functoolz.py:628, in pipe(data, *funcs)
#     608 """ Pipe a value through a sequence of functions
#     609
#     610 I.e. ``pipe(data, f, g, h)`` is equivalent to ``h(g(f(data)))``
#    (...)
#     625     thread_last
#     626 """
#     627 for func in funcs:
# --> 628     data = func(data)
#     629 return data
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/toolz/functoolz.py:304, in curry.__call__(self, *args, **kwargs)
#     302 def __call__(self, *args, **kwargs):
#     303     try:
# --> 304         return self._partial(*args, **kwargs)
#     305     except TypeError as exc:
#     306         if self._should_curry(args, kwargs, exc):
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/altair/utils/data.py:149, in to_values(data)
#     147     return {"values": data}
#     148 elif isinstance(data, pd.DataFrame):
# --> 149     data = sanitize_dataframe(data)
#     150     return {"values": data.to_dict(orient="records")}
#     151 elif isinstance(data, dict):
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/altair/utils/core.py:307, in sanitize_dataframe(df)
#     301         raise ValueError(
#     302             "Dataframe contains invalid column name: {0!r}. "
#     303             "Column names must be strings".format(col)
#     304         )
#     306 if isinstance(df.index, pd.MultiIndex):
# --> 307     raise ValueError("Hierarchical indices not supported")
#     308 if isinstance(df.columns, pd.MultiIndex):
#     309     raise ValueError("Hierarchical indices not supported")
#
# ValueError: Hierarchical indices not supported
# alt.LayerChart(...)

# %%
#INDUSTRIAL PETROLEUM VS SOLAR CONSUMPTION FOR ALL STATES (visualization D)

# Display chart
chart1 = alt.Chart(df).mark_line().encode(
    x=alt.X('Year', title='Year', axis=alt.Axis(format='d')), 
    y=alt.Y('Consumption.Industrial.Petroleum', title='Energy Consumption (Billion Btu)'),
    color=alt.Color('State', title='State'),
    tooltip=['Year', 'Consumption.Industrial.Petroleum', 'State']
)

chart2 = alt.Chart(df).mark_line().encode(
    x=alt.X('Year', title='Year', axis=alt.Axis(format='d')), 
    y=alt.Y('Consumption.Industrial.Solar'),
    color=alt.Color('State', title='State'),
    tooltip=['Year', 'Consumption.Industrial.Solar', 'State']
)

overlayed_chart = (chart1 + chart2).properties(
    title='Industrial Petroleum vs Solar Consumption by State since 1960',
    width=600,
    height=400).interactive()

# Add axis labels and legend titles
final_chart = overlayed_chart.configure_axis(
    labelFontSize=12,
    titleFontSize=14
).configure_legend(
    labelFontSize=12,
    titleFontSize=14,
   orient='bottom'  # change legend orientation to horizontal
)

final_chart
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/altair/vegalite/v4/api.py:374, in TopLevelMixin.to_dict(self, *args, **kwargs)
#     372 copy = self.copy(deep=False)
#     373 original_data = getattr(copy, "data", Undefined)
# --> 374 copy.data = _prepare_data(original_data, context)
#     376 if original_data is not Undefined:
#     377     context["data"] = original_data
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/altair/vegalite/v4/api.py:89, in _prepare_data(data, context)
#      87 # convert dataframes  or objects with __geo_interface__ to dict
#      88 if isinstance(data, pd.DataFrame) or hasattr(data, "__geo_interface__"):
# ---> 89     data = _pipe(data, data_transformers.get())
#      91 # convert string input to a URLData
#      92 if isinstance(data, str):
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/toolz/functoolz.py:628, in pipe(data, *funcs)
#     608 """ Pipe a value through a sequence of functions
#     609
#     610 I.e. ``pipe(data, f, g, h)`` is equivalent to ``h(g(f(data)))``
#    (...)
#     625     thread_last
#     626 """
#     627 for func in funcs:
# --> 628     data = func(data)
#     629 return data
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/toolz/functoolz.py:304, in curry.__call__(self, *args, **kwargs)
#     302 def __call__(self, *args, **kwargs):
#     303     try:
# --> 304         return self._partial(*args, **kwargs)
#     305     except TypeError as exc:
#     306         if self._should_curry(args, kwargs, exc):
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/altair/vegalite/data.py:19, in default_data_transformer(data, max_rows)
#      17 @curried.curry
#      18 def default_data_transformer(data, max_rows=5000):
# ---> 19     return curried.pipe(data, limit_rows(max_rows=max_rows), to_values)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/toolz/functoolz.py:628, in pipe(data, *funcs)
#     608 """ Pipe a value through a sequence of functions
#     609
#     610 I.e. ``pipe(data, f, g, h)`` is equivalent to ``h(g(f(data)))``
#    (...)
#     625     thread_last
#     626 """
#     627 for func in funcs:
# --> 628     data = func(data)
#     629 return data
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/toolz/functoolz.py:304, in curry.__call__(self, *args, **kwargs)
#     302 def __call__(self, *args, **kwargs):
#     303     try:
# --> 304         return self._partial(*args, **kwargs)
#     305     except TypeError as exc:
#     306         if self._should_curry(args, kwargs, exc):
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/altair/utils/data.py:149, in to_values(data)
#     147     return {"values": data}
#     148 elif isinstance(data, pd.DataFrame):
# --> 149     data = sanitize_dataframe(data)
#     150     return {"values": data.to_dict(orient="records")}
#     151 elif isinstance(data, dict):
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/altair/utils/core.py:307, in sanitize_dataframe(df)
#     301         raise ValueError(
#     302             "Dataframe contains invalid column name: {0!r}. "
#     303             "Column names must be strings".format(col)
#     304         )
#     306 if isinstance(df.index, pd.MultiIndex):
# --> 307     raise ValueError("Hierarchical indices not supported")
#     308 if isinstance(df.columns, pd.MultiIndex):
#     309     raise ValueError("Hierarchical indices not supported")
#
# ValueError: Hierarchical indices not supported
# alt.LayerChart(...)

# %%
#COMMERCIAL PETROLEUM VS SOLAR CONSUMPTION BY STATE (visualization E)

# Choose the State
choose_state = alt.selection_single(
    name='Choose',
    fields=['State'],
    bind=alt.binding_select(options=df['State'].unique().tolist()),
    init={'State': df['State'].unique().tolist()[0]}
)

# Display chart
chart1 = alt.Chart(df).mark_line().encode(
    x=alt.X('Year', title='Year', axis=alt.Axis(format='d')),  
    y=alt.Y('Consumption.Commercial.Petroleum', title='Energy Consumption (Billion Btu)'),
    color=alt.value('red'),  # use a static color value
    tooltip=['Year', 'Consumption.Commercial.Petroleum', 'State']
)

chart2 = alt.Chart(df).mark_line().encode(
    x=alt.X('Year', title='Year', axis=alt.Axis(format='d')),  
    y=alt.Y('Consumption.Commercial.Solar'),
    color=alt.value('blue'),  # use a static color value
    tooltip=['Year', 'Consumption.Commercial.Solar', 'State']
)

overlayed_chart = (chart1 + chart2).add_selection(choose_state).transform_filter(choose_state).properties(
    title='Commercial Petroleum vs Solar Consumption by State since 1960',
    width=600,
    height=400
).interactive()

# Add axis labels and legend titles
final_chart = overlayed_chart.configure_axis(
    labelFontSize=12,
    titleFontSize=14
).configure_legend(
    labelFontSize=12,
    titleFontSize=14,
   orient='bottom'  # change legend orientation to horizontal
)

final_chart
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py:2891, in Index.get_loc(self, key, method, tolerance)
#    2890 try:
# -> 2891     return self._engine.get_loc(casted_key)
#    2892 except KeyError as err:
#
# File pandas/_libs/index.pyx:70, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:101, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:1675, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:1683, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'State'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 7
#       1 #COMMERCIAL PETROLEUM VS SOLAR CONSUMPTION BY STATE (visualization E)
#       2
#       3 # Choose the State
#       4 choose_state = alt.selection_single(
#       5     name='Choose',
#       6     fields=['State'],
# ----> 7     bind=alt.binding_select(options=df['State'].unique().tolist()),
#       8     init={'State': df['State'].unique().tolist()[0]}
#       9 )
#      11 # Display chart
#      12 chart1 = alt.Chart(df).mark_line().encode(
#      13     x=alt.X('Year', title='Year', axis=alt.Axis(format='d')),
#      14     y=alt.Y('ConsumptionCommercialPetroleum', title='Energy Consumption (Billion Btu)'),
#      15     color=alt.value('red'),  # use a static color value
#      16     tooltip=['Year', 'ConsumptionCommercialPetroleum', 'State']
#      17 )
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py:2902, in DataFrame.__getitem__(self, key)
#    2900 if self.columns.nlevels > 1:
#    2901     return self._getitem_multilevel(key)
# -> 2902 indexer = self.columns.get_loc(key)
#    2903 if is_integer(indexer):
#    2904     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py:2893, in Index.get_loc(self, key, method, tolerance)
#    2891         return self._engine.get_loc(casted_key)
#    2892     except KeyError as err:
# -> 2893         raise KeyError(key) from err
#    2895 if tolerance is not None:
#    2896     tolerance = self._convert_tolerance(tolerance, np.asarray(key))
#
# KeyError: 'State'

# %%
#INDUSTRIAL PETROLEUM VS SOLAR CONSUMPTION BY STATE (visualization E)

# Choose the State
choose_state = alt.selection_single(
    name='Choose',
    fields=['State'],
    bind=alt.binding_select(options=df['State'].unique().tolist()),
    init={'State': df['State'].unique().tolist()[0]}
)

# Display chart
chart1 = alt.Chart(df).mark_line().encode(
    x=alt.X('Year', title='Year', axis=alt.Axis(format='d')),  
    y=alt.Y('ConsumptionIndustrialPetroleum', title='Energy Consumption (Billion Btu)'),
    color=alt.value('red'),  # use a static color value
    tooltip=['Year', 'ConsumptionIndustrialPetroleum', 'State']
)

chart2 = alt.Chart(df).mark_line().encode(
    x=alt.X('Year', title='Year', axis=alt.Axis(format='d')), 
    y=alt.Y('ConsumptionCommercialSolar'),
    color=alt.value('blue'),  # use a static color value
    tooltip=['Year', 'ConsumptionCommercialSolar', 'State']
)

overlayed_chart = (chart1 + chart2).add_selection(choose_state).transform_filter(choose_state).properties(
    title='Industrial Petroleum vs Solar Consumption by State since 1960',
    width=600,
    height=400
).interactive()

# Add axis labels and legend titles
final_chart = overlayed_chart.configure_axis(
    labelFontSize=12,
    titleFontSize=14
).configure_legend(
    labelFontSize=12,
    titleFontSize=14,
    orient='bottom'  # change legend orientation to horizontal
)

final_chart
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py:2891, in Index.get_loc(self, key, method, tolerance)
#    2890 try:
# -> 2891     return self._engine.get_loc(casted_key)
#    2892 except KeyError as err:
#
# File pandas/_libs/index.pyx:70, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:101, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:1675, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:1683, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'State'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 7
#       1 #INDUSTRIAL PETROLEUM VS SOLAR CONSUMPTION BY STATE (visualization E)
#       2
#       3 # Choose the State
#       4 choose_state = alt.selection_single(
#       5     name='Choose',
#       6     fields=['State'],
# ----> 7     bind=alt.binding_select(options=df['State'].unique().tolist()),
#       8     init={'State': df['State'].unique().tolist()[0]}
#       9 )
#      11 # Display chart
#      12 chart1 = alt.Chart(df).mark_line().encode(
#      13     x=alt.X('Year', title='Year', axis=alt.Axis(format='d')),
#      14     y=alt.Y('ConsumptionIndustrialPetroleum', title='Energy Consumption (Billion Btu)'),
#      15     color=alt.value('red'),  # use a static color value
#      16     tooltip=['Year', 'ConsumptionIndustrialPetroleum', 'State']
#      17 )
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py:2902, in DataFrame.__getitem__(self, key)
#    2900 if self.columns.nlevels > 1:
#    2901     return self._getitem_multilevel(key)
# -> 2902 indexer = self.columns.get_loc(key)
#    2903 if is_integer(indexer):
#    2904     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py:2893, in Index.get_loc(self, key, method, tolerance)
#    2891         return self._engine.get_loc(casted_key)
#    2892     except KeyError as err:
# -> 2893         raise KeyError(key) from err
#    2895 if tolerance is not None:
#    2896     tolerance = self._convert_tolerance(tolerance, np.asarray(key))
#
# KeyError: 'State'
